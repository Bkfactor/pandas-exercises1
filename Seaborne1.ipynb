# %%
import seaborn as sns
# %matplotlib inline 
import matplotlib.pyplot as mpl

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Distribution

# %%
distill= sns.displot(tips['total_bill'],kde=True,bins=100)
distill
mpl.show()

# %% [markdown]
# ### Joint Plot

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)
mpl.show()

# %%
##Pairplot

# %%
sns.pairplot(tips,hue ='sex',palette='coolwarm')
mpl.show()

# %%
## rug plot

# %%
sns.rugplot(tips['total_bill'])
mpl.show()

# %%
sns.kdeplot(tips['total_bill'])
mpl.show()

# %% [markdown]
# ## Categorical Data

# %%
import numpy as ny

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=ny.std)
mpl.show()

# %%
sns.countplot(x='sex',data=tips)
mpl.show()

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')
mpl.show()

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
mpl.show()

# %%
sns.stripplot(x='day',y='total_bill',data=tips, jitter=True, hue='sex' ,dodge=True)
mpl.show()

# %%
#sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
mpl.show()

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='violin')
mpl.show()
#general plot call

# %%
flights=sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
hm=tips.corr(numeric_only=True)

# %%
sns.heatmap(hm, annot=True,cmap='coolwarm')
mpl.show()

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
fphc=flights.pivot_table(index='month',columns='year', values='passengers', observed=False)

# %%
sns.heatmap(fphc,cmap='coolwarm',linecolor='black',linewidth=2)
mpl.show()
mpl.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>

# %%
sns.clustermap(fphc,cmap='coolwarm',standard_scale=1,linecolor='black',linewidth=2)
mpl.show()

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Grids

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)
mpl.show()

# %%
grid=sns.PairGrid(iris)
grid.map_diag(sns.histplot)
grid.map_upper(mpl.scatter)
grid.map_lower(sns.kdeplot)
mpl.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.histplot,'total_bill')
mpl.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex',markers=['o','v'],scatter_kws={'s':100},col='sex',row='time',
          aspect=0.6,height=4)
mpl.show()

# %%
## color Nnd Style

# %%
sns.set_style('ticks')
mpl.figure(figsize=(12,3))

sns.countplot(x='sex',data=tips)
sns.despine(left=True,bottom=True)
mpl.show()

# %%
sns.set_context('poster',font_scale=0.5)
sns.countplot(x='sex',data=tips)
mpl.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm')
mpl.show()
